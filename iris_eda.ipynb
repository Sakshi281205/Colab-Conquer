# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv("https://bit.ly/4nejNue")

# Convert specific columns to float
col_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
for col in col_names:
    data[col] = data[col].astype(float)

# Print first few rows
print("🔍 Dataset Preview:\n", data.head())

# Basic Statistics
print("\n📈 MEAN:\n", data[col_names].mean())
print("\n📊 MEDIAN:\n", data[col_names].median())
print("\n📌 MODE:\n", data[col_names].mode().iloc[0])  # Show first mode row
print("\n📉 STANDARD DEVIATION:\n", data[col_names].std())
print("\n📏 VARIANCE:\n", data[col_names].var())
print("\n⬆️ MAX:\n", data[col_names].max())
print("\n⬇️ MIN:\n", data[col_names].min())
print("\n🧾 DESCRIBE:\n", data.describe())

# Visualize Mean, Median, Std on a Line Plot
plt.figure(figsize=(10, 6))
plt.plot(col_names, data[col_names].mean(), label='Mean', marker='o')
plt.plot(col_names, data[col_names].median(), label='Median', marker='s')
plt.plot(col_names, data[col_names].std(), label='Standard Deviation', marker='^')
plt.title("📊 Iris Feature Statistics")
plt.xlabel("Features")
plt.ylabel("Values")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Histograms
plt.figure(figsize=(12, 8))
for i, col in enumerate(col_names):
    plt.subplot(2, 2, i + 1)
    plt.hist(data[col], bins=15, color='skyblue', edgecolor='black')
    plt.title(f'{col.capitalize()} Histogram')
    plt.xlabel(col)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.suptitle("🔍 Feature Distributions", fontsize=16, y=1.02)
plt.show()
# Out:
# 🔍 Dataset Preview:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# 📈 MEAN:
#  sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64
#
# 📊 MEDIAN:
#  sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64
#
# 📌 MODE:
#  sepal_length    5.0
# sepal_width     3.0
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64
#
# 📉 STANDARD DEVIATION:
#  sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64
#
# 📏 VARIANCE:
# ...
